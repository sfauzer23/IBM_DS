# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## In this notebook, Data Science Tools and Ecosystems are sumamrised.

# %% [markdown]
# **Objectives:**
# - List popular languages that data scientists use.
# - List commonly used libaries used by Data Scientists.
# - Code simple arithmatic expression in Python.
# - Learn to use markdown and RichText formatting.

# %% [markdown]
# ### Some of the popular languages that Data Scientists use are:
#
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# ### Some of the commonly used libraries used by Data Scientists include:
#
# 1. Pandas
# 2. Scikit-learn
# 3. Matplotlib

# %% [markdown]
# | Data Science Tools |
# | --- |
# | MySQL |
# | Apache Airflow |
# | Kibana |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
# This a simple arithmetic expression to mutiply then add integers

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
# This will convert 200 minutes to hours by diving by 60

# %%
200 / 60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Sabilus Fauzer
